# %% [markdown]
# ---
# title: "Engineering report template"
# jupyter: quarto_rep_pyenv
# execute:
#     enabled: true
# ---

# %% [markdown]
# ## Description
#
# This document intends to document blah blah blah

# %% [markdown]
# ## Standard packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import shutil
from scipy.constants import c, pi
from scipy import signal
from matplotlib import cm
from numpy.fft import fft, fftshift


import plotly.io as pio
import plotly.graph_objects as go
import os
import sys

# Detect if we are rendering in a headless/build environment like Quarto
# In Python, 'isinteractive' check is typically done via sys.flags
def detect_quarto_render():
    # 1. Check if we're even in a Jupyter/IPython environment
    try:
        shell = get_ipython().__class__.__name__ # type: ignore
        if shell == 'ZMQInteractiveShell':
            # 2. Check if Quarto is rendering by looking for its specific env vars
            # Quarto usually sets QUARTO_BIN_PATH or QUARTO_PROJECT_DIR during render
            is_quarto = any(key.startswith("QUARTO_") for key in os.environ)
            return is_quarto
        return False # Standard terminal script
    except NameError:
        return False # Not an interactive shell

is_rendering = detect_quarto_render()


#is_rendering = "QUARTO_ROUTES" in os.environ or not sys.flags.interactive

if is_rendering:
    # --- Light/High-Contrast Settings for Quarto HTML ---
    theme = "plotly_white"
    
    # Global layout defaults
    layout_defaults = dict(
        template=theme,
        paper_bgcolor="white",
        plot_bgcolor="white",
        legend=dict(
            bgcolor="rgba(0, 0, 0, 0.1)",
            orientation="h", # Horizontal often fits 600x300 better
            yanchor="bottom",
            y=1.02,
            xanchor="right",
            x=1
        ),
        xaxis=dict(showgrid=True, gridcolor="rgba(0,0,0,0.12)"),
        yaxis=dict(showgrid=True, gridcolor="rgba(0,0,0,0.12)"),
        width=650,
        height=325,
        autosize=False, # Prevents the browser from stretching it
        margin=dict(l=40, r=40, t=40, b=40),
        title = dict(
            x=0.5,
            xanchor='center'
        ),
        font = dict(
            family = "Helvetica",
            size = 14
        )
    )
else:
    # --- Dark/Interactive Theme ---
    theme = "plotly_dark"
    
    layout_defaults = dict(
        template=theme,
        paper_bgcolor="rgba(0,0,0,0)", # Transparent background
        plot_bgcolor="rgba(0,0,0,0)",  # Transparent plot area
        legend=dict(
            x=0.98,
            y=0.98,
            xanchor='right',
            yanchor='top',
            bgcolor="rgba(0, 0, 0, 0.4)",
            bordercolor="rgba(0,0,0,0)"
        ),
        xaxis=dict(showgrid=True, gridcolor="rgba(255,255,255,0.12)"),
        yaxis=dict(showgrid=True, gridcolor="rgba(255,255,255,0.12)"),
        width=650,
        height=325,
        autosize=False, # Prevents the browser from stretching it
        margin=dict(l=40, r=40, t=40, b=40),
        title = dict(
            x=0.5,
            xanchor='center'
        ),
        font = dict(
            family = "Helvetica",
            size = 14
        )
    )

# Apply the defaults globally
pio.templates.default = theme
pio.templates[theme].layout.update(layout_defaults); # type: ignore

# Calc demonstration packages
import handcalcs.render
handcalcs.set_option("display_precision", 2) # type: ignore
import forallpeople as si
si.environment('default', top_level= True)

# Type defining for pylance
from typing import TYPE_CHECKING
# This block is only seen by Pylance/IDE
if TYPE_CHECKING:
    m = si.m                    # type: ignore
    kg = si.kg                  # type: ignore
    Ohm = si.Ohm                # type: ignore
    V = si.V                    # type: ignore
    A = si.A                    # type: ignore
    Hz = si.Hz                  # type: ignore
    W = si.W                    # type: ignore
    C = si.C                    # type: ignore
    F = si.F                    # type: ignore
    Wb = si.Wb                  # type: ignore
    T = si.T                    # type: ignore
    H = si.H                    # type: ignore
    Celsius = si.Celsius        # type: ignore
    lux = si.lux                # type: ignore
    s = si.s                    # type: ignore
    # Add any other units you use frequently

# Some unit naming conventions
ohm = Ohm

# Spice simulation automation
# 1. We use the qspice module from Nunobrun
from qspice import QschEditor, SimRunner, SpiceEditor, RawRead

# Some helper functions are in the following module
import qspice_utils


# For debugging personal modules
# %load_ext autoreload
# %autoreload 2

print("Python stack loaded.")
# Out:
# Python stack loaded.

# %% [markdown]
# ## Topic 1
#
# Insert text for equation here. You can number and reference equation with @eq-sample
#
# $$
# x = a_2
# $$ {#eq-sample}
#
# Sample plot code below

# %%
# 1. Data Generation
# Julia 0:0.1:10 is equivalent to np.arange
x = np.arange(0, 10.1, 0.1) 
y = np.sin(2 * x)

# 2. Create the Figure
# This automatically inherits pio.templates.default
fig = go.Figure()

# 3. Add the trace (Equivalent to sp=1, alpha=0.5, and label)
fig.add_trace(go.Scatter(
    x=x, 
    y=y, 
    mode='lines',
    name="sin(x)",      # Equivalent to 'label'
    showlegend=True
))

# 4. Update Layout (Equivalent to title, xlabel, and ylabel)
fig.update_layout(
    title="Sine Wave",
    xaxis_title="Time",
    yaxis_title="Amplitude"
)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="9469b5ce-381e-46ae-82cd-9b7655affc27" class="plotly-graph-div" style="height:325px; width:650px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9469b5ce-381e-46ae-82cd-9b7655affc27")) {                    Plotly.newPlot(                        "9469b5ce-381e-46ae-82cd-9b7655affc27",                        [{"mode":"lines","name":"sin(x)","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAACamZmZmZm5P5qZmZmZmck\u002fNDMzMzMz0z+amZmZmZnZPwAAAAAAAOA\u002fNDMzMzMz4z9nZmZmZmbmP5qZmZmZmek\u002fzczMzMzM7D8AAAAAAADwP5qZmZmZmfE\u002fNDMzMzMz8z\u002fNzMzMzMz0P2dmZmZmZvY\u002fAAAAAAAA+D+amZmZmZn5PzQzMzMzM\u002fs\u002fzczMzMzM\..."},"y":{"dtype":"f8","bdata":"AAAAAAAAAAC80j0j\u002f23JP2tnK+k67Ng\u002fWkGlF40R4j\u002fN\u002fr\u002fClPTmP+4MCY9U7eo\u002fxVUaokPT7T8D4UTfzYjvP8VC4MeB\u002fO8\u002f8BW9gcIp7z9GtNHq9hjtPwjXqtkz3+k\u002fmNHD9WSd5T+7haC7\u002fH7gP8DlXSNycNU\u002fW9W2bTgQwj8yLeg5N+Otv3RM\u002fxDJWtC\u002f8dHwQ0FS3L+gwOz\u002fVpTjv64e3N25N+i\u002f2BLQ3\u002fLj67\u002fwKEUxhnPuv7rsXRNRzO+\u002f\u002fz0MmpTg778zmeD1ga\u002fuv9ckurJCRey\u002fcAUyl3y66L+09ZYXVjPkv8rfjscKvN2\u002fwKKwivHh0b8dzb7bWEW1vywqNS8r1r0\u002fkgnpL0vw0z8JEeqajZ\u002ffPwgKbcIIBuU\u002fD8njJbpl6T\u002f2KQV7N8LsPw\u002f4EK0y+e4\u002fL7eALBH07z97zyig0qjvPy4z6fd2Gu4\u002fmvctz99Y6z8tsbRXLoDnP93SykKkt+I\u002fkS8MNiZg2j9rm9UdqIfMP+JBRKi6Xpk\u002fKLcVCFdQxr8CbrPgZHTXv1JP8\u002fWeaOG\u002fS2bQmV9l5r+fjW\u002fvjX3qv9clLFJgh+2\u002fjRtzYNRj77\u002frky526\u002f\u002fvv3+ldYhsVe+\u002fSk8AqCNr7b\u002fbVTOinFTqvwhZwoRbMea\u002fpWXX95or4b96T+uCOu3WvyTW0IKEMsW\u002fes5pQAo3oT\u002fcw8ErHaLNPwbFgUgE5No\u002fiNnPJ0Ty4j8W90LHKLHnPyz7GOtAfus\u002fynS0QsEy7j9FXnwyDrPvP\u002ft\u002fPpfV7+8\u002f9wctI6vm7j+Z+aIYIaLsPzM0TGZcOek\u002f6MLOcSjP5D8ccFz3JyHfPzeQQolKZtM\u002fpZGmTL6Vuz9wmgEUNYe3v\u002fggXwgCbdK\u002fh4lfbSk83r9oZIG0Xmvkv4uCQp5C6Oi\u002fgbDH+vJm7L8riEKsxMPuv7bsoPea5u+\u002fMgzmmt3D779BiPEi71zuv8Qi\u002fcgewOu\u002fJx4TaBYI6L8lCflcylrjv37wsFPsz9u\u002fZuoQPNWcz7\u002fHMx5LvFypv8+E9SgtL8M\u002fYaTgLd\u002f41T8dTmBq9LzgPyQkqF6l0uU\u002fnaCGgZ0J6j\u002fgPF312DbtPw=="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777 ...

# %%
# %%render params
# # Here is an example of a Handcalcs
# R_1 = 1 * ohm
# I_1 = 1e3 * A
# Out:
# $$
# \begin{aligned}
# R_{1} &= 1.00\ \mathrm{\Omega} \;
#  &I_{1} &= 1.00\ \mathrm{kA} \;
# \end{aligned}
# $$

# %%
# %%render 2
# P_1 = R_1 * I_1**2
# Out:
# $$
# \begin{aligned}
# P_{1} &= R_{1} \cdot \left( I_{1} \right) ^{ 2 }  = 1.00\ \mathrm{\Omega} \cdot \left( 1.00\ \mathrm{kA} \right) ^{ 2 } &= 1.00\ \mathrm{MW}
# \end{aligned}
# $$
